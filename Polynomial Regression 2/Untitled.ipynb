# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv('salary.csv')
df.head()
# Out:
#             Position  Level   Salary
# 0   Business Analyst       1   45000
# 1  Junior Consultant       2   50000
# 2  Senior Consultant       3   60000
# 3            Manager       4   80000
# 4     Country Manger       5  110000

# %%
df=pd.get_dummies(df,columns=['Position'])
df=df.astype(int)
df.head()
# Out:
#    Level   Salary  Position_Business Analyst  Position_C.level  Position_CEO  \
# 0       1   45000                          1                 0             0
# 1       2   50000                          0                 0             0
# 2       3   60000                          0                 0             0
# 3       4   80000                          0                 0             0
# 4       5  110000                          0                 0             0
#
#    Position_Country Manger  Position_Junior Consultant  Position_Manager  \
# 0                        0                           0                 0
# 1                        0                           1                 0
# 2                        0                           0                 0
# 3                        0                           0                 1
# 4                        1                           0                 0
#
#    Position_Partner  Position_Region Manager  Position_Senior Consultant  \
# 0                 0                        0                           0
# 1                 0                        0                           0
# 2                 0                        0                           1
# 3                 0                        0                           0
# 4                 0                        0                           0
#
#    Position_Senior Partner
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0

# %%
X = df.drop(columns='Salary')
y=df['Salary']

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
poly=PolynomialFeatures(degree=2)
X_poly=poly.fit_transform(X_train)
model=LinearRegression()
model.fit(X_poly,y_train)
# Out:
# LinearRegression()

# %%
y_poly_pred=model.predict(X_poly)

# %%
train_error = mean_squared_error(y_train, y_train_pred)
test_error = mean_squared_error(y_test, y_test_pred)
print(train_error)
print(test_error)
# Out:
# 2.0069595627125724e-16
# 25386372124.315243

# %%
plt.scatter(X_test.iloc[:,0].values, y_test, s=10, label="Test Data")

plt.plot(X_test.iloc[:,0].values, y_poly_pred, label="Polynomial fit",color='red', alpha=0.6)

# Assigning labels to the axes
plt.xlabel("x values")
plt.ylabel("y values")
plt.legend()
plt.show()
